# %%
import os
import sys
import tarfile
from six.moves import urllib
from ipywidgets import FloatProgress
from IPython.display import display

DATA_URL = 'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'


def cifar10_download(data_dir='/tmp/cifar10_data', print_progress=True):
    """Download and extract the tarball from Alex's website."""
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)

    if os.path.exists(os.path.join(data_dir, 'cifar-10-batches-py')):
        print('cifar dataset already downloaded')
        return

    filename = DATA_URL.split('/')[-1]
    filepath = os.path.join(data_dir, filename)

    if not os.path.exists(filepath):
        f = FloatProgress(min=0, max=100)
        display(f)
        sys.stdout.write('\r>> Downloading %s ' % (filename))        

        def _progress(count, block_size, total_size):
            if print_progress:
                f.value = 100.0 * count * block_size / total_size

        filepath, _ = urllib.request.urlretrieve(DATA_URL, filepath, _progress)
        print()
        statinfo = os.stat(filepath)
        print('Successfully downloaded', filename, statinfo.st_size, 'bytes.')

    tarfile.open(filepath, 'r:gz').extractall(data_dir)

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
bucket = sagemaker_session.default_bucket()

# %%
# Download cifar10 datset
cifar10_download()
# Out:
# cifar dataset already downloaded

# %%
sagemaker_session.upload_data(path='/tmp/cifar10_data/cifar-10-batches-py', key_prefix='cifar10_data')
# Out:
# 's3://sagemaker-us-west-2-500842391574/cifar10_data'

# %%
# Configure the hyperparameters from the instructor
training_image = '500842391574.dkr.ecr.us-west-2.amazonaws.com/horovod:latest'
#hosting_image = '<<TO BE PROVIDED>>'

# Training data channel
channels = {'training': 's3://'+bucket+'/cifar10_data'}

# Optmized training parameters
hyperparameters = {'learning_rate': .0001, 'epochs': 20, 'batch_size': 32}

# Output of trained model
output_location = "s3://{}".format(bucket)

# %%
channels
# Out:
# {'training': 's3://sagemaker-us-west-2-500842391574/cifar10_data'}

# %%
from sagemaker.estimator import Estimator
# SageMaker estimator
horovod_estimator = Estimator(
    training_image,
    role=role,
    output_path=output_location,
    train_instance_count=2,
    train_instance_type='ml.p3.8xlarge',
    hyperparameters=hyperparameters,
    sagemaker_session=sagemaker_session
)

# %%
# Start training
horovod_estimator.fit(channels)
# Out:
# INFO:sagemaker:Creating training-job with name: horovod-2018-09-05-17-19-29-023
# .........................
# Creating SageMaker trainer environment:
# TrainerEnvironment(input_dir='/opt/ml/input', input_config_dir='/opt/ml/input/config', model_dir='/opt/ml/model', output_dir='/opt/ml/output', hyperparameters={'epochs': '20', 'learning_rate': '0.0001', 'batch_size': '32'}, resource_config={'current_host': 'algo-1', 'network_interface_name': 'ethwe', 'hosts': ['algo-1', 'algo-2']}, input_data_config={'training': {'TrainingInputMode': 'File', 'RecordWrapperType': 'None', 'S3DistributionType': 'FullyReplicated'}}, output_data_dir='/opt/ml/output/data', hosts=['algo-1', 'algo-2'], channel_dirs={'training': '/opt/ml/input/data/training'}, current_host='algo-1', available_gpus=4, available_cpus=32)
# hosts that aren't SSHable yet: ['algo-1', 'algo-2']
# testing connection to host algo-1
# can't connect to host algo-1
# testing connection to host algo-2
# can't connect to host algo-2
# hosts that aren't SSHable yet: ['algo-1', 'algo-2']
# testing connection to host algo-1
# can't connect to host algo-1
# testing connection to host algo-2
# can't connect to host algo-2
# Creating SageMaker trainer environment:
# TrainerEnvironment(input_dir='/opt/ml/input', input_config_dir='/opt/ml/input/config', model_dir='/opt/ml/model', output_dir='/opt/ml/output', hyperparameters={'epochs': '20', 'learning_rate': '0.0001', 'batch_size': '32'}, resource_config={'current_host': 'algo-2', 'network_interface_name': 'ethwe', 'hosts': ['algo-1', 'algo-2']}, input_data_config={'training': {'TrainingInputMode': 'File', 'RecordWrapperType': 'None', 'S3DistributionType': 'FullyReplicated'}}, output_data_dir='/opt/ml/output/data', hosts=['algo-1', 'algo-2'], channel_dirs={'training': '/opt/ml/input/data/training'}, current_host='algo-2', available_gpus=4, available_cpus=32)
# Worker node algo-2 is waiting for MPI to start training process
# hosts that aren't SSHable yet: ['algo-1', 'algo-2']
# testing connection to host algo-1
# can connect to host algo-1
# hosts that aren't SSHable yet: ['algo-2']
# testing connection to host algo-2
# can't connect to host algo-2
# hosts that aren't SSHable yet: ['algo-2']
# testing connection to host algo-2
# can connect to host algo-2
# network interface name: ethwe
# ('Running MPI script:\n\n%s', '#!/usr/bin/env bash\ntouch /mpi_is_running\n/usr/bin/python train.py --batch_size 32 --epochs 20 --learning_rate 0.0001 --training /opt/ml/input/data/training --output_data_dir /opt/ml/output/data\nEXIT_CODE=$?\ntouch /mpi_is_finished\nexit ${EXIT_CODE}\n')
# Warning: Permanently added 'algo-2,10.32.0.4' (ECDSA) to the list of known hosts.#015
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# MPI started training process on worker node algo-2
# 2018-09-05 17:23:34.912087: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-05 17:23:34.912065: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-05 17:23:34.912111: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-05 17:23:34.912175: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-05 17:23:34.911346: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-05 17:23:34.911347: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-05 17:23:34.911360: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-05 17:23:34.911380: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-05 17:23:37.277275: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-09-05 17:23:37.277274: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-09-05 17:23:37.277275: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-09-05 17:23:37.279628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1b.0
# totalMemory: 15.78GiB freeMemory: 15.37GiB
# 2018-09-05 17:23:37.279655: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 0
# 2018-09-05 17:23:37.279673: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1d.0
# totalMemory: 15.78GiB freeMemory: 15.37GiB
# 2018-09-05 17:23:37.279706: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 2
# 2018-09-05 17:23:37.279718: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1c.0
# totalMemory: 15.78GiB freeMemory: 15.37GiB
# 2018-09-05 17:23:37.279736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 1
# 2018-09-05 17:23:37.291775: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-09-05 17:23:37.294913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1e.0
# totalMemory: 15.78GiB freeMemory: 15.37GiB
# 2018-09-05 17:23:37.294937: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 3
# 2018-09-05 17:23:37.357030: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-09-05 17:23:37.357026: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-09-05 17:23:37.357027: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-09-05 17:23:37.357028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-09-05 17:23:37.360153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1b.0
# totalMemory: 15.78GiB freeMemory: 15.37GiB
# 2018-09-05 17:23:37.360178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 0
# 2018-09-05 17:23:37.360205: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1e.0
# totalMemory: 15.78GiB freeMemory: 15.37GiB
# 2018-09-05 17:23:37.360223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 3
# 2018-09-05 17:23:37.360257: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1d.0
# totalMemory: 15.78GiB freeMemory: 15.37GiB
# 2018-09-05 17:23:37.360281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 2
# 2018-09-05 17:23:37.360326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1c.0
# totalMemory: 15.78GiB freeMemory: 15.37GiB
# 2018-09-05 17:23:37.360348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 1
# 2018-09-05 17:23:38.135377: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-05 17:23:38.135423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      0
# 2018-09-05 17:23:38.135432: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 0:   N
# 2018-09-05 17:23:38.136295: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14862 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1b.0, compute capability: 7.0)
# 2018-09-05 17:23:38.155506: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-05 17:23:38.155551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      3
# 2018-09-05 17:23:38.155560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 3:   N
# 2018-09-05 17:23:38.155893: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14862 MB memory) -> physical GPU (device: 3, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# 2018-09-05 17:23:38.160195: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-05 17:23:38.160238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      1
# 2018-09-05 17:23:38.160246: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 1:   N
# 2018-09-05 17:23:38.159202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-05 17:23:38.159237: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      2
# 2018-09-05 17:23:38.159245: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 2:   N
# 2018-09-05 17:23:38.159572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14862 MB memory) -> physical GPU (device: 2, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1d.0, compute capability: 7.0)
# 2018-09-05 17:23:38.161103: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14862 MB memory) -> physical GPU (device: 1, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1c.0, compute capability: 7.0)
# 2018-09-05 17:23:38.182417: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-05 17:23:38.182463: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      3
# 2018-09-05 17:23:38.182471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 3:   N
# 2018-09-05 17:23:38.182813: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14862 MB memory) -> physical GPU (device: 3, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# 2018-09-05 17:23:38.185355: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-05 17:23:38.185388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      0
# 2018-09-05 17:23:38.185397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 0:   N
# 2018-09-05 17:23:38.185744: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14862 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1b.0, compute capability: 7.0)
# 2018-09-05 17:23:38.209328: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-05 17:23:38.209375: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      2
# 2018-09-05 17:23:38.209384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 2:   N
# 2018-09-05 17:23:38.209759: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14862 MB memory) -> physical GPU (device: 2, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1d.0, compute capability: 7.0)
# 2018-09-05 17:23:38.269537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-05 17:23:38.269581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      1
# 2018-09-05 17:23:38.269589: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 1:   N
# 2018-09-05 17:23:38.269939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14862 MB memory) -> physical GPU (device: 1, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1c.0, compute capability: 7.0)
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Not using data augmentation.
# Not using data augmentation.
# Not using data augmentation.
# Not using data augmentation.
# Not using data augmentation.
# Not using data augmentation.
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# algo-1:37:179 [0] misc/ibvwrap.cu:61 WARN Failed to open libibverbs.so[.1]
# algo-1:37:179 [0] INFO Using internal Network Socket
# algo-1:37:179 [0] INFO Using NCCL Low-latency algorithm for sizes below 16384
# algo-1:37:179 [0] INFO NET : Using interface ethwe:10.40.0.3<0>
# algo-1:37:179 [0] INFO NET/Socket : 1 interfaces found
# NCCL version 2.2.13+cuda9.0
#
# algo-1:39:178 [2] misc/ibvwrap.cu:61 WARN Failed to open libibverbs.so[.1]
# algo-1:39:178 [2] INFO Using internal Network Socket
# algo-1:39:178 [2] INFO Using NCCL Low-latency algorithm for sizes below 16384
#
# algo-1:41:181 [3] misc/ibvwrap.cu:61 WARN Failed to open libibverbs.so[.1]
# algo-1:41:181 [3] INFO Using internal Network Socket
# algo-1:41:181 [3] INFO Using NCCL Low-latency algorithm for sizes below 16384
#
# algo-1:38:180 [1] misc/ibvwrap.cu:61 WARN Failed to open libibverbs.so[.1]
# algo-1:38:180 [1] INFO Using internal Network Socket
# algo-1:38:180 [1] INFO Using NCCL Low-latency algorithm for sizes below 16384
#
# algo-2:48:188 [3] misc/ibvwrap.cu:61 WARN Failed to open libibverbs.so[.1]
# algo-2:48:188 [3] INFO Using internal Network Socket
# algo-2:48:188 [3] INFO Using NCCL Low-latency algorithm for sizes below 16384
#
# algo-2:46:186 [0] misc/ibvwrap.cu:61 WARN Failed to open libibverbs.so[.1]
# algo-2:46:186 [0] INFO Using internal Network Socket
# algo-2:46:186 [0] INFO Using NCCL Low-latency algorithm for sizes below 16384
#
# algo-2:45:185 [2] misc/ibvwrap.cu:61 WARN Failed to open libibverbs.so[.1]
# algo-2:45:185 [2] INFO Using internal Network Socket
# algo-2:45:185 [2] INFO Using NCCL Low-latency algorithm for sizes below 16384
#
# algo-2:47:187 [1] misc/ibvwrap.cu:61 WARN Failed to open libibverbs.so[.1]
# algo-2:47:187 [1] INFO Using internal Network Socket
# algo-2:47:187 [1] INFO Using NCCL Low-latency algorithm for sizes below 16384
# algo-1:39:178 [2] INFO comm 0x7fd7c8209aa0 rank 2 nranks 8
# algo-1:39:178 [2] INFO NET : Using interface ethwe:10.40.0.3<0>
# algo-1:39:178 [2] INFO NET/Socket : 1 interfaces found
# algo-1:41:181 [3] INFO comm 0x7fd9f8209bf0 rank 3 nranks 8
# algo-1:41:181 [3] INFO NET : Using interface ethwe:10.40.0.3<0>
# algo-1:41:181 [3] INFO NET/Socket : 1 interfaces found
# algo-1:38:180 [1] INFO comm 0x7f9278209b00 rank 1 nranks 8
# algo-1:38:180 [1] INFO NET : Using interface ethwe:10.40.0.3<0>
# algo-1:38:180 [1] INFO NET/Socket : 1 interfaces found
# algo-1:37:179 [0] INFO comm 0x7f6e34232d60 rank 0 nranks 8
# algo-2:48:188 [3] INFO comm 0x7f60d4211dc0 rank 7 nranks 8
# algo-2:48:188 [3] INFO NET : Using interface ethwe:10.32.0.4<0>
# algo-2:48:188 [3] INFO NET/Socket : 1 interfaces found
# algo-2:47:187 [1] INFO comm 0x7f89f42126f0 rank 5 nranks 8
# algo-2:47:187 [1] INFO NET : Using interface ethwe:10.32.0.4<0>
# algo-2:47:187 [1] INFO NET/Socket : 1 interfaces found
# algo-2:45:185 [2] INFO comm 0x7fc8702122c0 rank 6 nranks 8
# algo-2:45:185 [2] INFO NET : Using interface ethwe:10.32.0.4<0>
# algo-2:45:185 [2] INFO NET/Socket : 1 interfaces found
# algo-2:46:186 [0] INFO comm 0x7fa9c0209b00 rank 4 nranks 8
# algo-2:46:186 [0] INFO NET : Using interface ethwe:10.32.0.4<0>
# algo-2:46:186 [0] INFO NET/Socket : 1 interfaces found
# algo-1:37:179 [0] INFO Using 256 threads
# algo-1:37:179 [0] INFO Min Comp Cap 7
# algo-1:37:179 [0] INFO NCCL_SINGLE_RING_THRESHOLD=262144
# algo-1:37:179 [0] INFO Ring 00 :    0   1   2   3   4   5   6   7
# algo-1:38:180 [1] INFO Ring 00 : 1[1] -> 2[2] via P2P/IPC
# algo-1:39:178 [2] INFO Ring 00 : 2[2] -> 3[3] via P2P/IPC
# algo-2:47:187 [1] INFO Ring 00 : 5[1] -> 6[2] via P2P/IPC
# algo-2:45:185 [2] INFO Ring 00 : 6[2] -> 7[3] via P2P/IPC
# algo-1:37:179 [0] INFO 7 -> 0 via NET/Socket/0
# algo-1:37:179 [0] INFO Ring 00 : 0[0] -> 1[1] via P2P/IPC
# algo-2:46:186 [0] INFO 3 -> 4 via NET/Socket/0
# algo-2:46:186 [0] INFO Ring 00 : 4[0] -> 5[1] via P2P/IPC
# algo-1:37:179 [0] INFO Launch mode Parallel
#  - 58s - loss: 2.0524 - acc: 0.2428 - val_loss: 1.8538 - val_acc: 0.3438
# Epoch 2/20
#  - 58s - loss: 2.0456 - acc: 0.2396 - val_loss: 1.8037 - val_acc: 0.3695
# Epoch 2/20
#  - 58s - loss: 2.0338 - acc: 0.2435 - val_loss: 1.7503 - val_acc: 0.3759
# Epoch 2/20
#  - 58s - loss: 2.0232 - acc: 0.2484 - val_loss: 1.8008 - val_acc: 0.3677
# Epoch 2/20
#  - 58s - loss: 2.0621 - acc: 0.2362 - val_loss: 1.8430 - val_acc: 0.3534
# Epoch 2/20
#  - 58s - loss: 2.0162 - acc: 0.2522 - val_loss: 1.8234 - val_acc: 0.3582
# Epoch 2/20
#  - 58s - loss: 2.0623 - acc: 0.2362 - val_loss: 1.8717 - val_acc: 0.3358
# Epoch 2/20
#  - 58s - loss: 2.0786 - acc: 0.2276 - val_loss: 1.8837 - val_acc: 0.3494
# Epoch 2/20
#  - 50s - loss: 1.7957 - acc: 0.3479 - val_loss: 1.6605 - val_acc: 0.4061
# Epoch 3/20
#  - 50s - loss: 1.7454 - acc: 0.3644 - val_loss: 1.6179 - val_acc: 0.4187
# Epoch 3/20
#  - 50s - loss: 1.7773 - acc: 0.3543 - val_loss: 1.6354 - val_acc: 0.4146
# Epoch 6/20
#  - 50s - loss: 1.4848 - acc: 0.4635 - val_loss: 1.3807 - val_acc: 0.5084
# Epoch 6/20
#  - 50s - loss: 1.5114 - acc: 0.4518 - val_loss: 1.4280 - val_acc: 0.4840
# Epoch 6/20
#  - 50s - loss: 1.4855 - acc: 0.4614 - val_loss: 1.4353 - val_acc: 0.4865
# Epoch 6/20
#  - 50s - loss: 1.4553 - acc: 0.4733 - val_loss: 1.3458 - val_acc: 0.5247
# Epoch 6/20
#  - 50s - loss: 1.4299 - acc: 0.4843 - val_loss: 1.3215 - val_acc: 0.5273
# Epoch 7/20
#  - 50s - loss: 1.4197 - acc: 0.4872 - val_loss: 1.3477 - val_acc: 0.5242
# Epoch 7/20
#  - 50s - loss: 1.4427 - acc: 0.4778 - val_loss: 1.3782 - val_acc: 0.5105
# Epoch 7/20
#  - 50s - loss: 1.4472 - acc: 0.4762 - val_loss: 1.3590 - val_acc: 0.5134
# Epoch 7/20
#  - 50s - loss: 1.4321 - acc: 0.4791 - val_loss: 1.3404 - val_acc: 0.5178
# Epoch 7/20
#  - 50s - loss: 1.4327 - acc: 0.4814 - val_loss: 1.3368 - val_acc: 0.5239
# Epoch 7/20
#  - 50s - loss: 1.4316 - acc: 0.4807 - val_loss: 1.3332 - val_acc: 0.5235
# Epoch 7/20
#  - 50s - loss: 1.3994 - acc: 0.4945 - val_loss: 1.2986 - val_acc: 0.5393
# Epoch 7/20
#  - 50s - loss: 1.3803 - acc: 0.5036 - val_loss: 1.2883 - val_acc: 0.5360
# Epoch 8/20
#  - 50s - loss: 1.3897 - acc: 0.5014 - val_loss: 1.2825 - val_acc: 0.5419
# Epoch 8/20
#  - 50s - loss: 1.3764 - acc: 0.5046 - val_loss: 1.2960 - val_acc: 0.5338
# Epoch 8/20
#  - 50s - loss: 1.3886 - acc: 0.4994 - val_loss: 1.2825 - val_acc: 0.5414
# Epoch 8/20
#  - 50s - loss: 1.3665 - acc: 0.5098 - val_loss: 1.2928 - val_acc: 0.5424
# Epoch 8/20
#  - 50s - loss: 1.3518 - acc: 0.5150 - val_loss: 1.2411 - val_acc: 0.5617
# Epoch 8/20
#  - 50s - loss: 1.3893 - acc: 0.5011 - val_loss: 1.3023 - val_acc: 0.5369
# Epoch 8/20
#  - 50s - loss: 1.3782 - acc: 0.5034 - val_loss: 1.2752 - val_acc: 0.5456
# Epoch 8/20
#  - 51s - loss: 1.3354 - acc: 0.5210 - val_loss: 1.2345 - val_acc: 0.5608
# Epoch 9/20
#  - 51s - loss: 1.3402 - acc: 0.5209 - val_loss: 1.2409 - val_acc: 0.5563
# Epoch 9/20
#  - 51s - loss: 1.3446 - acc: 0.5167 - val_loss: 1.2423 - val_acc: 0.5582
# Epoch 9/20
#  - 51s - loss: 1.3361 - acc: 0.5197 - val_loss: 1.2278 - val_acc: 0.5621
# Epoch 9/20
#  - 51s - loss: 1.3210 - acc: 0.5270 - val_loss: 1.2281 - val_acc: 0.5667
# Epoch 9/20
#  - 51s - loss: 1.3432 - acc: 0.5185 - val_loss: 1.2557 - val_acc: 0.5570
# Epoch 9/20
#  - 51s - loss: 1.3331 - acc: 0.5198 - val_loss: 1.2376 - val_acc: 0.5591
# Epoch 9/20
#  - 51s - loss: 1.3049 - acc: 0.5344 - val_loss: 1.2018 - val_acc: 0.5731
# Epoch 9/20
#  - 52s - loss: 1.2924 - acc: 0.5380 - val_loss: 1.1835 - val_acc: 0.5846
# Epoch 10/20
#  - 52s - loss: 1.2791 - acc: 0.5414 - val_loss: 1.1927 - val_acc: 0.5776
# Epoch 10/20
#  - 52s - loss: 1.2932 - acc: 0.5369 - val_loss: 1.1904 - val_acc: 0.5784
# Epoch 10/20
#  - 52s - loss: 1.2925 - acc: 0.5366 - val_loss: 1.2065 - val_acc: 0.5777
# Epoch 10/20
#  - 52s - loss: 1.2955 - acc: 0.5368 - val_loss: 1.2014 - val_acc: 0.5743
# Epoch 10/20
#  - 52s - loss: 1.2654 - acc: 0.5486 - val_loss: 1.1733 - val_acc: 0.5817
# Epoch 10/20
#  - 52s - loss: 1.2955 - acc: 0.5357 - val_loss: 1.2041 - val_acc: 0.5771
# Epoch 10/20
#  - 52s - loss: 1.2996 - acc: 0.5342 - val_loss: 1.2098 - val_acc: 0.5730
# Epoch 10/20
#  - 50s - loss: 1.2499 - acc: 0.5509 - val_loss: 1.2007 - val_acc: 0.5729
# Epoch 11/20
#  - 50s - loss: 1.2613 - acc: 0.5460 - val_loss: 1.1722 - val_acc: 0.5921
# Epoch 11/20
#  - 50s - loss: 1.2404 - acc: 0.5546 - val_loss: 1.1530 - val_acc: 0.5938
# Epoch 11/20
#  - 50s - loss: 1.2559 - acc: 0.5514 - val_loss: 1.1534 - val_acc: 0.5930
# Epoch 11/20
#  - 50s - loss: 1.2529 - acc: 0.5505 - val_loss: 1.1701 - val_acc: 0.5862
# Epoch 11/20
#  - 50s - loss: 1.2564 - acc: 0.5499 - val_loss: 1.1554 - val_acc: 0.5958
# Epoch 11/20
#  - 50s - loss: 1.2546 - acc: 0.5537 - val_loss: 1.1746 - val_acc: 0.5846
# Epoch 11/20
#  - 50s - loss: 1.2270 - acc: 0.5628 - val_loss: 1.1570 - val_acc: 0.5960
# Epoch 11/20
#  - 50s - loss: 1.2130 - acc: 0.5670 - val_loss: 1.1413 - val_acc: 0.5962
# Epoch 12/20
#  - 50s - loss: 1.2048 - acc: 0.5694 - val_loss: 1.1157 - val_acc: 0.6070
# Epoch 12/20
#  - 50s - loss: 1.2066 - acc: 0.5708 - val_loss: 1.1163 - val_acc: 0.6045
# Epoch 12/20
#  - 50s - loss: 1.2238 - acc: 0.5616 - val_loss: 1.1255 - val_acc: 0.6004
# Epoch 12/20
#  - 50s - loss: 1.2188 - acc: 0.5627 - val_loss: 1.1193 - val_acc: 0.6055
# Epoch 12/20
#  - 50s - loss: 1.2167 - acc: 0.5677 - val_loss: 1.1360 - val_acc: 0.6020
# Epoch 12/20
#  - 50s - loss: 1.2218 - acc: 0.5626 - val_loss: 1.1195 - val_acc: 0.6046
# Epoch 12/20
#  - 50s - loss: 1.1920 - acc: 0.5750 - val_loss: 1.1415 - val_acc: 0.5986
# Epoch 12/20
#  - 51s - loss: 1.1787 - acc: 0.5798 - val_loss: 1.1535 - val_acc: 0.5932
# Epoch 13/20
#  - 51s - loss: 1.1670 - acc: 0.5850 - val_loss: 1.0751 - val_acc: 0.6229
# Epoch 13/20
#  - 51s - loss: 1.1795 - acc: 0.5817 - val_loss: 1.0846 - val_acc: 0.6182
# Epoch 13/20
#  - 51s - loss: 1.1850 - acc: 0.5785 - val_loss: 1.0901 - val_acc: 0.6150
# Epoch 13/20
#  - 51s - loss: 1.1774 - acc: 0.5803 - val_loss: 1.1151 - val_acc: 0.6040
# Epoch 13/20
#  - 51s - loss: 1.1896 - acc: 0.5765 - val_loss: 1.0963 - val_acc: 0.6103
# Epoch 13/20
#  - 51s - loss: 1.1844 - acc: 0.5776 - val_loss: 1.0882 - val_acc: 0.6156
# Epoch 13/20
#  - 51s - loss: 1.1541 - acc: 0.5912 - val_loss: 1.0650 - val_acc: 0.6205
# Epoch 13/20
#  - 50s - loss: 1.1433 - acc: 0.5932 - val_loss: 1.0859 - val_acc: 0.6139
# Epoch 14/20
#  - 50s - loss: 1.1410 - acc: 0.5938 - val_loss: 1.0660 - val_acc: 0.6191
# Epoch 14/20
#  - 50s - loss: 1.1361 - acc: 0.5943 - val_loss: 1.0602 - val_acc: 0.6236
# Epoch 14/20
#  - 50s - loss: 1.1566 - acc: 0.5902 - val_loss: 1.0759 - val_acc: 0.6198
# Epoch 14/20
#  - 50s - loss: 1.1539 - acc: 0.5871 - val_loss: 1.0809 - val_acc: 0.6189
# Epoch 14/20
#  - 50s - loss: 1.1473 - acc: 0.5918 - val_loss: 1.0572 - val_acc: 0.6326
# Epoch 14/20
#  - 50s - loss: 1.1234 - acc: 0.6020 - val_loss: 1.1009 - val_acc: 0.6134
# Epoch 14/20
#  - 50s - loss: 1.1545 - acc: 0.5900 - val_loss: 1.0627 - val_acc: 0.6268
# Epoch 14/20
#  - 51s - loss: 1.1119 - acc: 0.6050 - val_loss: 1.0401 - val_acc: 0.6333
# Epoch 15/20
#  - 51s - loss: 1.1084 - acc: 0.6069 - val_loss: 1.0270 - val_acc: 0.6340
# Epoch 15/20
#  - 51s - loss: 1.1048 - acc: 0.6077 - val_loss: 1.0197 - val_acc: 0.6423
# Epoch 15/20
#  - 51s - loss: 1.1228 - acc: 0.6009 - val_loss: 1.0334 - val_acc: 0.6352
# Epoch 15/20
#  - 51s - loss: 1.1221 - acc: 0.5996 - val_loss: 1.0476 - val_acc: 0.6321
# Epoch 15/20
#  - 51s - loss: 1.0905 - acc: 0.6153 - val_loss: 1.0184 - val_acc: 0.6396
# Epoch 15/20
