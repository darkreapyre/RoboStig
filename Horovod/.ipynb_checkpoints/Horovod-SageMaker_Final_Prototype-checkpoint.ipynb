# %%
import os
import sys
import tarfile
from six.moves import urllib
from ipywidgets import FloatProgress
from IPython.display import display

DATA_URL = 'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'


def cifar10_download(data_dir='/tmp/cifar10_data', print_progress=True):
    """Download and extract the tarball from Alex's website."""
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)

    if os.path.exists(os.path.join(data_dir, 'cifar-10-batches-py')):
        print('cifar dataset already downloaded')
        return

    filename = DATA_URL.split('/')[-1]
    filepath = os.path.join(data_dir, filename)

    if not os.path.exists(filepath):
        f = FloatProgress(min=0, max=100)
        display(f)
        sys.stdout.write('\r>> Downloading %s ' % (filename))        

        def _progress(count, block_size, total_size):
            if print_progress:
                f.value = 100.0 * count * block_size / total_size

        filepath, _ = urllib.request.urlretrieve(DATA_URL, filepath, _progress)
        print()
        statinfo = os.stat(filepath)
        print('Successfully downloaded', filename, statinfo.st_size, 'bytes.')

    tarfile.open(filepath, 'r:gz').extractall(data_dir)

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
bucket = sagemaker_session.default_bucket()

# %%
# Download cifar10 datset
cifar10_download()
# Out:
# cifar dataset already downloaded

# %%
sagemaker_session.upload_data(path='/tmp/cifar10_data/cifar-10-batches-py', key_prefix='cifar10_data')
# Out:
# 's3://sagemaker-us-west-2-500842391574/cifar10_data'

# %%
# Configure the hyperparameters from the instructor
training_image = '500842391574.dkr.ecr.us-west-2.amazonaws.com/horovod:latest'
#hosting_image = '<<TO BE PROVIDED>>'

# Training data channel
channels = {'training': 's3://'+bucket+'/cifar10_data'}

# Optmized training parameters
hyperparameters = {'learning_rate': .0001, 'epochs': 20, 'batch_size': 32}

# Output of trained model
output_location = "s3://{}".format(bucket)

# %%
from sagemaker.estimator import Estimator
# SageMaker estimator
horovod_estimator = Estimator(
    training_image,
    role=role,
    output_path=output_location,
    train_instance_count=2,
    train_instance_type='ml.p3.2xlarge',
    hyperparameters=hyperparameters,
    sagemaker_session=sagemaker_session
)

# %%
# Start training
horovod_estimator.fit(channels)
# Out:
# INFO:sagemaker:Creating training-job with name: horovod-2018-09-05-20-55-02-671
# ........................
# Creating SageMaker trainer environment:
# TrainerEnvironment(input_dir='/opt/ml/input', input_config_dir='/opt/ml/input/config', model_dir='/opt/ml/model', output_dir='/opt/ml/output', hyperparameters={'epochs': '20', 'learning_rate': '0.0001', 'batch_size': '32'}, resource_config={'current_host': 'algo-1', 'network_interface_name': 'ethwe', 'hosts': ['algo-1', 'algo-2']}, input_data_config={'training': {'TrainingInputMode': 'File', 'RecordWrapperType': 'None', 'S3DistributionType': 'FullyReplicated'}}, output_data_dir='/opt/ml/output/data', hosts=['algo-1', 'algo-2'], channel_dirs={'training': '/opt/ml/input/data/training'}, current_host='algo-1', available_gpus=1, available_cpus=8)
# hosts that aren't SSHable yet: ['algo-1', 'algo-2']
# testing connection to host algo-1
# can't connect to host algo-1
# testing connection to host algo-2
# can't connect to host algo-2
# hosts that aren't SSHable yet: ['algo-1', 'algo-2']
# testing connection to host algo-1
# can't connect to host algo-1
# testing connection to host algo-2
# can't connect to host algo-2
# hosts that aren't SSHable yet: ['algo-1', 'algo-2']
# testing connection to host algo-1
# can't connect to host algo-1
# testing connection to host algo-2
# can't connect to host algo-2
# Creating SageMaker trainer environment:
# TrainerEnvironment(input_dir='/opt/ml/input', input_config_dir='/opt/ml/input/config', model_dir='/opt/ml/model', output_dir='/opt/ml/output', hyperparameters={'epochs': '20', 'learning_rate': '0.0001', 'batch_size': '32'}, resource_config={'current_host': 'algo-2', 'network_interface_name': 'ethwe', 'hosts': ['algo-1', 'algo-2']}, input_data_config={'training': {'TrainingInputMode': 'File', 'RecordWrapperType': 'None', 'S3DistributionType': 'FullyReplicated'}}, output_data_dir='/opt/ml/output/data', hosts=['algo-1', 'algo-2'], channel_dirs={'training': '/opt/ml/input/data/training'}, current_host='algo-2', available_gpus=1, available_cpus=8)
# Worker node algo-2 is waiting for MPI to start training process
# hosts that aren't SSHable yet: ['algo-1', 'algo-2']
# testing connection to host algo-1
# can connect to host algo-1
# hosts that aren't SSHable yet: ['algo-2']
# testing connection to host algo-2
# can't connect to host algo-2
# hosts that aren't SSHable yet: ['algo-2']
# testing connection to host algo-2
# can connect to host algo-2
# network interface name: ethwe
#
#  MPI Command to run: mpirun --allow-run-as-root --host algo-1,algo-2 -bind-to none -map-by slot -mca pml ob1 -mca btl ^openib -x PATH -x LD_LIBRARY_PATH -x LD_PRELOAD=/libchangehostname.so -x NCCL_DEBUG=INFO -x NCCL_SOCKET_IFNAME=ethwe -np 2  /mpi_script.sh
# ('Running MPI script:\n\n%s', '#!/usr/bin/env bash\ntouch /mpi_is_running\n/usr/bin/python train.py --batch_size 32 --epochs 20 --learning_rate 0.0001 --training /opt/ml/input/data/training --output_data_dir /opt/ml/output/data\nEXIT_CODE=$?\ntouch /mpi_is_finished\nexit ${EXIT_CODE}\n')
# Warning: Permanently added 'algo-2,10.40.0.3' (ECDSA) to the list of known hosts.#015
# Using TensorFlow backend.
# Using TensorFlow backend.
# MPI started training process on worker node algo-2
# 2018-09-05 20:58:59.017765: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-05 20:58:59.017750: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-09-05 20:58:59.196095: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-09-05 20:58:59.196577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1e.0
# totalMemory: 15.78GiB freeMemory: 15.37GiB
# 2018-09-05 20:58:59.196605: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 0
# 2018-09-05 20:58:59.286909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-09-05 20:58:59.287438: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1e.0
# totalMemory: 15.78GiB freeMemory: 15.37GiB
# 2018-09-05 20:58:59.287466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 0
# 2018-09-05 20:59:00.406574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-05 20:59:00.406623: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      0
# 2018-09-05 20:59:00.406632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 0:   N
# 2018-09-05 20:59:00.407436: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14863 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# 2018-09-05 20:59:00.440791: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-05 20:59:00.440830: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      0
# 2018-09-05 20:59:00.440838: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 0:   N
# 2018-09-05 20:59:00.441557: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14863 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
#
# algo-1:32:43 [0] misc/ibvwrap.cu:61 WARN Failed to open libibverbs.so[.1]
# algo-1:32:43 [0] INFO Using internal Network Socket
# algo-1:32:43 [0] INFO Using NCCL Low-latency algorithm for sizes below 16384
# algo-1:32:43 [0] INFO NET : Using interface ethwe:10.32.0.4<0>
# algo-1:32:43 [0] INFO NET/Socket : 1 interfaces found
# NCCL version 2.2.13+cuda9.0
#
# algo-2:39:50 [0] misc/ibvwrap.cu:61 WARN Failed to open libibverbs.so[.1]
# algo-2:39:50 [0] INFO Using internal Network Socket
# algo-2:39:50 [0] INFO Using NCCL Low-latency algorithm for sizes below 16384
# algo-1:32:43 [0] INFO comm 0x7f57641da740 rank 0 nranks 2
# algo-2:39:50 [0] INFO comm 0x7f21fc1d91e0 rank 1 nranks 2
# algo-2:39:50 [0] INFO NET : Using interface ethwe:10.40.0.3<0>
# algo-2:39:50 [0] INFO NET/Socket : 1 interfaces found
# algo-1:32:43 [0] INFO Using 256 threads
# algo-1:32:43 [0] INFO Min Comp Cap 7
# algo-1:32:43 [0] INFO NCCL_SINGLE_RING_THRESHOLD=262144
# algo-1:32:43 [0] INFO Ring 00 :    0   1
# algo-2:39:50 [0] INFO 0 -> 1 via NET/Socket/0
# algo-1:32:43 [0] INFO 1 -> 0 via NET/Socket/0
# algo-1:32:43 [0] INFO Launch mode Parallel
#  - 51s - loss: 1.8610 - acc: 0.3164 - val_loss: 1.6658 - val_acc: 0.4017
# Epoch 2/20
#  - 51s - loss: 1.8599 - acc: 0.3171 - val_loss: 1.5846 - val_acc: 0.4333
# Epoch 2/20
#  - 40s - loss: 1.5499 - acc: 0.4377 - val_loss: 1.4546 - val_acc: 0.4817
# Epoch 3/20
#  - 40s - loss: 1.5932 - acc: 0.4163 - val_loss: 1.4410 - val_acc: 0.4777
# Epoch 3/20
#  - 40s - loss: 1.4292 - acc: 0.4842 - val_loss: 1.2985 - val_acc: 0.5412
# Epoch 4/20
#  - 40s - loss: 1.4609 - acc: 0.4721 - val_loss: 1.3874 - val_acc: 0.5087
# Epoch 4/20
#  - 39s - loss: 1.3417 - acc: 0.5198 - val_loss: 1.2544 - val_acc: 0.5513
# Epoch 5/20
#  - 39s - loss: 1.3730 - acc: 0.5067 - val_loss: 1.2731 - val_acc: 0.5467
# Epoch 5/20
#  - 39s - loss: 1.2758 - acc: 0.5463 - val_loss: 1.2093 - val_acc: 0.5727
# Epoch 6/20
#  - 39s - loss: 1.3022 - acc: 0.5351 - val_loss: 1.2207 - val_acc: 0.5698
# Epoch 6/20
#  - 40s - loss: 1.2218 - acc: 0.5678 - val_loss: 1.1311 - val_acc: 0.6048
# Epoch 7/20
#  - 40s - loss: 1.2441 - acc: 0.5579 - val_loss: 1.1665 - val_acc: 0.5896
# Epoch 7/20
#  - 41s - loss: 1.1714 - acc: 0.5846 - val_loss: 1.0977 - val_acc: 0.6117
# Epoch 8/20
#  - 41s - loss: 1.1896 - acc: 0.5805 - val_loss: 1.0964 - val_acc: 0.6127
# Epoch 8/20
#  - 40s - loss: 1.1335 - acc: 0.6025 - val_loss: 1.0783 - val_acc: 0.6233
# Epoch 9/20
#  - 40s - loss: 1.1483 - acc: 0.5949 - val_loss: 1.0685 - val_acc: 0.6219
# Epoch 9/20
#  - 40s - loss: 1.0927 - acc: 0.6159 - val_loss: 1.0671 - val_acc: 0.6217
# Epoch 10/20
#  - 40s - loss: 1.1055 - acc: 0.6107 - val_loss: 1.0391 - val_acc: 0.6352
# Epoch 10/20
#  - 41s - loss: 1.0595 - acc: 0.6280 - val_loss: 0.9937 - val_acc: 0.6496
# Epoch 11/20
#  - 41s - loss: 1.0686 - acc: 0.6248 - val_loss: 0.9975 - val_acc: 0.6515
# Epoch 11/20
#  - 42s - loss: 1.0253 - acc: 0.6398 - val_loss: 1.0422 - val_acc: 0.6444
# Epoch 12/20
#  - 42s - loss: 1.0376 - acc: 0.6359 - val_loss: 0.9644 - val_acc: 0.6629
# Epoch 12/20
#  - 40s - loss: 0.9995 - acc: 0.6510 - val_loss: 0.9314 - val_acc: 0.6767
# Epoch 13/20
#  - 40s - loss: 1.0108 - acc: 0.6451 - val_loss: 0.9867 - val_acc: 0.6540
# Epoch 13/20
#  - 41s - loss: 0.9745 - acc: 0.6576 - val_loss: 0.9055 - val_acc: 0.6911
# Epoch 14/20
#  - 41s - loss: 0.9876 - acc: 0.6545 - val_loss: 0.9262 - val_acc: 0.6735
# Epoch 14/20
#  - 39s - loss: 0.9512 - acc: 0.6674 - val_loss: 0.8959 - val_acc: 0.6902
# Epoch 15/20
#  - 39s - loss: 0.9696 - acc: 0.6607 - val_loss: 0.9109 - val_acc: 0.6782
# Epoch 15/20
#  - 41s - loss: 0.9290 - acc: 0.6778 - val_loss: 0.8704 - val_acc: 0.6991
# Epoch 16/20
#  - 41s - loss: 0.9432 - acc: 0.6699 - val_loss: 0.9165 - val_acc: 0.6835
# Epoch 16/20
#  - 40s - loss: 0.9093 - acc: 0.6811 - val_loss: 0.9627 - val_acc: 0.6644
# Epoch 17/20
#  - 40s - loss: 0.9283 - acc: 0.6753 - val_loss: 0.8811 - val_acc: 0.6936
# Epoch 17/20
#  - 40s - loss: 0.8888 - acc: 0.6908 - val_loss: 0.8628 - val_acc: 0.7035
# Epoch 18/20
#  - 40s - loss: 0.9143 - acc: 0.6813 - val_loss: 0.8912 - val_acc: 0.6905
# Epoch 18/20
#  - 40s - loss: 0.8796 - acc: 0.6937 - val_loss: 0.8399 - val_acc: 0.7164
# Epoch 19/20
#  - 40s - loss: 0.8980 - acc: 0.6859 - val_loss: 0.8703 - val_acc: 0.6963
# Epoch 19/20
#  - 40s - loss: 0.8648 - acc: 0.6980 - val_loss: 0.8118 - val_acc: 0.7190
# Epoch 20/20
#  - 40s - loss: 0.8851 - acc: 0.6888 - val_loss: 0.8921 - val_acc: 0.6891
# Epoch 20/20
#  - 39s - loss: 0.8451 - acc: 0.7068 - val_loss: 0.8186 - val_acc: 0.7215
#  - 39s - loss: 0.8713 - acc: 0.6966 - val_loss: 0.8195 - val_acc: 0.7141
# Saved trained model at /opt/ml/output/data/keras_model.h5
# Training process started by MPI on worker node algo-2 stopped
# Billable seconds: 1898
